# %%
import requests
import os
from bs4 import BeautifulSoup
from tqdm import tqdm

names = ['Elizabeth Olsen', 'Aaron Taylor Johansson', 'Paul Bettany', 'Josh Brolin', 'Jeremy Runner', 'Orlando Bloom', 'Keira Knightley', 'Geoffery Hush', 'Bill Nighy', 'Kirsten Dunst', 'Willem Dafoe', 'Alfred Molina', 'Nicolas Cage']

# %%
from bing_image_downloader import downloader
img_url = []
for name in tqdm(names):
    string = '{}'.format(name) + ' front face'
    downloader.download(string, limit=100, output_dir='dataset', adult_filter_off=True, force_replace=False, timeout=60, verbose=True)
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
# [%] Downloading Images to /home/mist/Desktop/ML/Supervised Learning/Project/Movie_Recommender_System_V2/dataset/Elizabeth Olsen front face
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/1d/6b/ee/1d6beea7250d793a18a6de2cc12c59ff.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/06/ac/f2/06acf2a79d191b667de5f7282c26186b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://assets.rebelmouse.io/eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpbWFnZSI6Imh0dHBzOi8vYXNzZXRzLnJibC5tcy8xODQ5MzE2My9vcmlnaW4uanBnIiwiZXhwaXJlc19hdCI6MTYzMzY0NjM4NX0.KL-g_peTNvDm9qbRxMGvDcWsYO3PzXadFKRJ-Bw1kgc/img.jpg?width=980
# ...
